# %% [markdown]
# ### Datos Estudiantes

# %%
# Importación de librerias
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Mostrar toda las columnas
pd.set_option("display.max_columns", 20)

# %%
# Leer datos 
df_excel = pd.read_csv("StudentsPerformance.csv")

# %%
# Mostrar dataframe
df_excel
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# Método Pandas estadistica descriptiva
df_excel.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Calculo del promedio
df_excel["math score"].mean()
# Out:
# 66.089

# %%
# Valor máximo
df_excel["math score"].max()
# Out:
# 100

# %%
# Valor Minimo
df_excel["math score"].min()
# Out:
# 0

# %%
# Conteo valores
df_excel["math score"].count()
# Out:
# 1000

# %%
# calculo el promedio de las 3 notas (matemáticas, lectura y escritura)
df_excel["average"] = (df_excel["math score"]  + df_excel["reading score"] + df_excel["writing score"])/3

# %%
# otra forma de calculo el promedio de las 3 notas (matemáticas, lectura y escritura)
# agrega una columna llamada average
df_excel["average"] = df_excel.mean(axis=1)

# %%
# Muestra los 5 primeros campos
df_excel.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score    average
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
# Conteo por valor
df_excel["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# Metodo if condition
df_excel["pass/fail"] = np.where(df_excel["average"] > 70, "Pass", "Fail")
df_excel.sample(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 616  female        group E           bachelor's degree      standard
# 21   female        group B                some college  free/reduced
# 847    male        group D                 high school      standard
# 832    male        group A           bachelor's degree      standard
# 864    male        group C          associate's degree      standard
# 527  female        group C                 high school  free/reduced
# 422  female        group D             master's degree  free/reduced
# 395    male        group A                 high school  free/reduced
# 580  female        group D            some high school      standard
# 913  female        group C           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 616                    none          37             45             38
# 21                completed          65             75             70
# 847                    none          64             54             50
# 832                    none          64             60             58
# 864                    none          97             93             91
# 527                    none          36             53             43
# 422               completed          47             58             67
# 395                    none          48             45             41
# 580                    none          81             97             96
# 913               completed          47             62             66
#
#        average pass/fail
# 616  40.000000      Fail
# 21   70.000000      Fail
# 847  56.000000      Fail
# 832  60.666667      Fail
# 864  93.666667      Pass
# 527  44.000000      Fail
# 422  57.333333      Fail
# 395  44.666667      Fail
# 580  91.333333      Pass
# 913  58.333333      Fail

# %%
# Metodo multiple if conditions
conditions = [
    (df_excel["average"]>=90),
    (df_excel["average"]>=80) & (df_excel["average"]<90),
    (df_excel["average"]>=70) & (df_excel["average"]<80),
    (df_excel["average"]>=60) & (df_excel["average"]<70),
    (df_excel["average"]>=50) & (df_excel["average"]<60),
    (df_excel["average"]<50)
]

# %%
# Calificación
values = ["A", "B", "C", "D", "E", "F"]

# %%
# Columna de acuerdo a la condición de grades
df_excel["grades"] = np.select(conditions, values)
df_excel.sample(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 308  female        group B          associate's degree  free/reduced
# 788    male        group C          associate's degree  free/reduced
# 368  female        group A            some high school  free/reduced
# 800    male        group C            some high school      standard
# 307    male        group C            some high school      standard
# 893    male        group D            some high school      standard
# 675  female        group B                some college      standard
# 993  female        group D           bachelor's degree  free/reduced
# 469    male        group C                some college      standard
# 439    male        group D            some high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 308                    none          53             71             67
# 788                    none          68             65             61
# 368                    none          44             64             58
# 800               completed          67             73             68
# 307                    none          51             52             44
# 893               completed          88             74             75
# 675               completed          50             64             66
# 993                    none          62             72             74
# 469                    none          91             74             76
# 439               completed          89             88             82
#
#        average pass/fail grades
# 308  63.666667      Fail      D
# 788  64.666667      Fail      D
# 368  55.333333      Fail      E
# 800  69.333333      Fail      D
# 307  49.000000      Fail      F
# 893  79.000000      Pass      C
# 675  60.000000      Fail      D
# 993  69.333333      Fail      D
# 469  80.333333      Pass      B
# 439  86.333333      Pass      B

# %%
# solo obtener el promedio para género femenino
df_female = df_excel[df_excel['gender'] == 'female']
df_female
#df_female.value_counts()

#df_male = df_excel[df_excel['gender'] == 'male']
#df_male
#df_male.value_counts()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 993                    none          62             72             74
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#        average pass/fail grades
# 0    72.666667      Pass      C
# 1    82.333333      Pass      B
# 2    92.666667      Pass      A
# 5    77.333333      Pass      C
# 6    91.666667      Pass      A
# ..         ...       ...    ...
# 993  69.333333      Fail      D
# 995  94.000000      Pass      A
# 997  65.000000      Fail      D
# 998  74.333333      Pass      C
# 999  83.000000      Pass      B
#
# [518 rows x 11 columns]

# %%
# solo obtener el promedio para el genero femenino y grupo B
df_sumifs = df_excel[(df_excel['gender'] == 'female') & (df_excel['race/ethnicity'] == 'group B')]
df_sumifs["sum"] = df_sumifs["math score"] + df_sumifs["reading score"] + df_sumifs["writing score"] 
df_sumifs.sample(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 923  female        group B          associate's degree  free/reduced
# 17   female        group B            some high school  free/reduced
# 667  female        group B           bachelor's degree  free/reduced
# 513  female        group B            some high school      standard
# 558  female        group B          associate's degree  free/reduced
# 396  female        group B                 high school  free/reduced
# 360  female        group B                 high school      standard
# 224  female        group B          associate's degree      standard
# 722  female        group B            some high school  free/reduced
# 152  female        group B          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 923                    none          54             65             65
# 17                     none          18             32             28
# 667                    none          77             85             87
# 513               completed          54             61             62
# 558                    none          53             70             70
# 396                    none          50             67             63
# 360                    none          58             62             59
# 224               completed          52             66             73
# 722               completed          74             90             88
# 152               completed          59             70             66
#
#        average pass/fail grades  sum
# 923  61.333333      Fail      D  184
# 17   26.000000      Fail      F   78
# 667  83.000000      Pass      B  249
# 513  59.000000      Fail      E  177
# 558  64.333333      Fail      D  193
# 396  60.000000      Fail      D  180
# 360  59.666667      Fail      E  179
# 224  63.666667      Fail      D  191
# 722  84.000000      Pass      B  252
# 152  65.000000      Fail      D  195

# %%
excel_1 = "StudentsPerformance.csv"
df_excel_1 = pd.read_csv(excel_1)
df_excel_1 = df_excel_1.reset_index()
df_excel_1 = df_excel_1.rename(columns={"index":"id"})
df_excel_1
# Out:
#       id  gender race/ethnicity parental level of education         lunch  \
# 0      0  female        group B           bachelor's degree      standard
# 1      1  female        group C                some college      standard
# 2      2  female        group B             master's degree      standard
# 3      3    male        group A          associate's degree  free/reduced
# 4      4    male        group C                some college      standard
# ..   ...     ...            ...                         ...           ...
# 995  995  female        group E             master's degree      standard
# 996  996    male        group C                 high school  free/reduced
# 997  997  female        group C                 high school  free/reduced
# 998  998  female        group D                some college      standard
# 999  999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 9 columns]

# %%
excel_2 = "LanguageScore.csv"
df_excel_2 = pd.read_csv(excel_2)
df_excel_2 = df_excel_2.reset_index()

df_excel_2
# Out:
#     index   id  language score
# 0       0    1              74
# 1       1    2              67
# 2       2    3              34
# 3       3    4              33
# 4       4    5              75
# ..    ...  ...             ...
# 95     95   96              67
# 96     96   97              87
# 97     97   98              66
# 98     98   99              94
# 99     99  100              75
#
# [100 rows x 3 columns]

# %%
# calificación registro en la posición 0
df_excel_1.loc[df_excel_1["id"] == 0, "math score"]
# Out:
# 0    72
# Name: math score, dtype: int64

# %%
# Unir dos tablas en base a una columna en común (ID)
df_excel_3 = pd.merge(df_excel_1, df_excel_2, on = "id", how="right")
df_excel_3.sample(10)
# Out:
#      id  gender race/ethnicity parental level of education         lunch  \
# 15   16    male        group C                 high school      standard
# 46   47  female        group C                 high school      standard
# 47   48  female        group D          associate's degree  free/reduced
# 77   78  female        group D            some high school      standard
# 53   54  female        group C            some high school  free/reduced
# 1     2  female        group B             master's degree      standard
# 60   61    male        group A            some high school  free/reduced
# 99  100    male        group B                some college      standard
# 50   51    male        group E          associate's degree  free/reduced
# 76   77    male        group A           bachelor's degree      standard
#
#    test preparation course  math score  reading score  writing score  index  \
# 15                    none          88             89             86     15
# 46                    none          66             71             76     46
# 47               completed          57             74             76     47
# 77               completed          61             74             72     77
# 53               completed          71             84             87     53
# 1                     none          90             95             93      1
# 60                    none          39             39             34     60
# 99                    none          79             67             67     99
# 50               completed          77             69             68     50
# 76               completed          80             78             81     76
#
#     language score
# 15              65
# 46              75
# 47              94
# 77              96
# 53              60
# 1               67
# 60              41
# 99              75
# 50              64
# 76              48

# %%
# reemplazar valores vacíos
df_excel_3["language score"] = df_excel_3["language score"].fillna("0")
# alternativa df_excel_3["language score"].fillna("0", inplace = True)
df_excel_3.sample(15)
# Out:
#     id  gender race/ethnicity parental level of education         lunch  \
# 88  89  female        group D            some high school      standard
# 57  58    male        group D                some college      standard
# 96  97  female        group E                some college      standard
# 11  12  female        group B                 high school      standard
# 15  16    male        group C                 high school      standard
# 54  55  female        group C                 high school  free/reduced
# 42  43    male        group B                some college  free/reduced
# 58  59  female        group C            some high school  free/reduced
# 38  39    male        group B          associate's degree  free/reduced
# 61  62    male        group A          associate's degree  free/reduced
# 24  25    male        group A             master's degree  free/reduced
# 47  48  female        group D          associate's degree  free/reduced
# 98  99  female        group D           bachelor's degree      standard
# 17  18    male        group C             master's degree  free/reduced
# 69  70  female        group D                some college  free/reduced
#
#    test preparation course  math score  reading score  writing score  index  \
# 88                    none          73             86             82     88
# 57               completed          58             59             58     57
# 96               completed          63             72             70     96
# 11                    none          65             81             73     11
# 15                    none          88             89             86     15
# 54                    none          33             41             43     54
# 42               completed          59             65             66     42
# 58                    none           0             17             10     58
# 38                    none          57             56             57     38
# 61                    none          62             61             55     61
# 24                    none          73             74             72     24
# 47               completed          57             74             76     47
# 98                    none          65             67             62     98
# 17               completed          46             42             46     17
# 69               completed          58             63             73     69
#
#     language score
# 88              32
# 57              56
# 96              87
# 11              41
# 15              65
# 54             100
# 42              47
# 58              73
# 38              79
# 61              63
# 24              43
# 47              94
# 98              94
# 17              36
# 69              60

# %%
# concatenar dos tablas
df_excel_3 = pd.concat(
    [df_excel_1.set_index("id"), df_excel_2.set_index("id")], axis = 1 
)
df_excel_3
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# id
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  index  \
# id
# 0                      none          72             72             74    NaN
# 1                 completed          69             90             88    0.0
# 2                      none          90             95             93    1.0
# 3                      none          47             57             44    2.0
# 4                      none          76             78             75    3.0
# ..                      ...         ...            ...            ...    ...
# 995               completed          88             99             95    NaN
# 996                    none          62             55             55    NaN
# 997               completed          59             71             65    NaN
# 998               completed          68             78             77    NaN
# 999                    none          77             86             86    NaN
#
#      language score
# id
# 0               NaN
# 1              74.0
# 2              67.0
# 3              34.0
# 4              33.0
# ..              ...
# 995             NaN
# 996             NaN
# 997             NaN
# 998             NaN
# 999             NaN
#
# [1000 rows x 10 columns]

# %% [markdown]
# #### Tablas pivote

# %%
df_excel = pd.read_csv("StudentsPerformance.csv")

# %%
# tabla pivote de la suma de los resultados de matematicas y escritura
df_excel.pivot_table(index = "race/ethnicity", values = ["math score", "writing score"], aggfunc = "sum")
# Out:
#                 math score  writing score
# race/ethnicity
# group A               5485           5578
# group B              12056          12464
# group C              20564          21637
# group D              17649          18378
# group E              10335           9997

# %%
# mejorar formato de la data
df_excel["gender"].str.title()
# Out:
# 0      Female
# 1      Female
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995    Female
# 996      Male
# 997    Female
# 998    Female
# 999    Female
# Name: gender, Length: 1000, dtype: object

# %%
# extraer datos de una columna
df_excel["group"] = df_excel["race/ethnicity"].str.extract(r'([A-Z])')
df_excel["group"]
# Out:
# 0      B
# 1      C
# 2      B
# 3      A
# 4      C
#       ..
# 995    E
# 996    C
# 997    C
# 998    D
# 999    D
# Name: group, Length: 1000, dtype: object

# %%
# identificar celdas vacias
df_excel["gender"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df_excel.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# group                          1000
# dtype: int64

# %% [markdown]
# ### gráficos básicos

# %%
import matplotlib.pyplot as plt

# %%
df_pivot = df_excel.pivot_table(index = "race/ethnicity", values = ["math score", "writing score"], aggfunc = "sum")
df_pivot
# Out:
#                 math score  writing score
# race/ethnicity
# group A               5485           5578
# group B              12056          12464
# group C              20564          21637
# group D              17649          18378
# group E              10335           9997

# %%
df_plot = df_pivot.reset_index()
df_plot
# Out:
#   race/ethnicity  math score  writing score
# 0        group A        5485           5578
# 1        group B       12056          12464
# 2        group C       20564          21637
# 3        group D       17649          18378
# 4        group E       10335           9997

# %%
# bar plot
plt.bar(df_plot["race/ethnicity"], df_plot["math score"])
plt.show()

# %%
# piechart
plt.pie(df_plot["writing score"], labels=df_plot["race/ethnicity"], autopct= "%.0f %%")
plt.show()
